# %% [markdown]
# #### Summary
# This dataset describes the evolution of results in the Portuguese Parliamentary Elections of October 6th 2019.
# The data spans a time interval of 4 hours and 25 minutes, in intervals of 5 minutes, concerning the results of the 27 parties involved in the electoral event.
#
# We are supposed to predict the Final Mandates.

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# import the dataset
df=pd.read_csv("ElectionData.csv")
pd.set_option('display.max_columns',None)
df.head()
# Out:
#    TimeElapsed                 time        territoryName  totalMandates  \
# 0            0  2019-10-06 20:10:02  Território Nacional              0
# 1            0  2019-10-06 20:10:02  Território Nacional              0
# 2            0  2019-10-06 20:10:02  Território Nacional              0
# 3            0  2019-10-06 20:10:02  Território Nacional              0
# 4            0  2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
# 3                226         3092                 1081        9652
# 4                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# 0                   2.5       8874                  2.3             51.36
# 1                   2.5       8874                  2.3             51.36
# 2                   2.5       8874                  2.3             51.36
# 3                   2.5       8874                  2.3             51.36
# 4                   2.5       8874                  2.3             51.36
#
#    subscribedVoters  totalVoters  pre.blankVotes  pre.blankVotesPercentage  \
# 0            752529       386497            8317                      1.94
# 1            752529       386497            8317                      1.94
# 2            752529       386497            8317                      1.94
# 3            752529       386497            8317                      1.94
# 4            752529       386497            8317                      1.94
#
#    pre.nullVotes  pre.nullVotesPercentage  pre.votersPercentage  \
# 0           8171                     1.91                 52.66
# 1           8171                     1.91                 52.66
# 2           8171                     1.91                 52.66
# 3           8171                     1.91                 52.66
# 4           8171                     1.91                 52.66
#
#    pre.subscribedVoters  pre.totalVoters    Party  Mandates  Percentage  \
# 0                813743           428546       PS         0       38.29
# 1                813743           428546  PPD/PSD         0       33.28
# 2                813743           428546     B.E.         0        6.81
# 3                813743           428546   CDS-PP         0        4.90
# 4                813743           428546  PCP-PEV         0        4.59
#
#    validVotesPercentage   Votes  Hondt  FinalMandates
# 0                 40.22  147993     94            106
# 1                 34.95  128624     81             77
# 2                  7.15   26307     16             19
# 3                  5.14   18923     12              5
# 4                  4.83   17757     11             12

# %%
# checking the shape of the dataset
df.shape
# There are 26368 rows and seven columns in the dataset
# Out:
# (21643, 28)

# %%
# checking the datatypes of the dataset
df.dtypes
# Apart from time district and party all are in numerical datatypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# FinalMandates                 int64
# dtype: object

# %%
# checking missing data
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# There are no missing values in the dataset
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
# The time is in object datatype. We need to convert it into Datetime
#df['time']=pd.to_datetime(df['time'])
#df['time']

# %%
df.head(3)
# Out:
#    TimeElapsed                 time        territoryName  totalMandates  \
# 0            0  2019-10-06 20:10:02  Território Nacional              0
# 1            0  2019-10-06 20:10:02  Território Nacional              0
# 2            0  2019-10-06 20:10:02  Território Nacional              0
#
#    availableMandates  numParishes  numParishesApproved  blankVotes  \
# 0                226         3092                 1081        9652
# 1                226         3092                 1081        9652
# 2                226         3092                 1081        9652
#
#    blankVotesPercentage  nullVotes  nullVotesPercentage  votersPercentage  \
# 0                   2.5       8874                  2.3             51.36
# 1                   2.5       8874                  2.3             51.36
# 2                   2.5       8874                  2.3             51.36
#
#    subscribedVoters  totalVoters  pre.blankVotes  pre.blankVotesPercentage  \
# 0            752529       386497            8317                      1.94
# 1            752529       386497            8317                      1.94
# 2            752529       386497            8317                      1.94
#
#    pre.nullVotes  pre.nullVotesPercentage  pre.votersPercentage  \
# 0           8171                     1.91                 52.66
# 1           8171                     1.91                 52.66
# 2           8171                     1.91                 52.66
#
#    pre.subscribedVoters  pre.totalVoters    Party  Mandates  Percentage  \
# 0                813743           428546       PS         0       38.29
# 1                813743           428546  PPD/PSD         0       33.28
# 2                813743           428546     B.E.         0        6.81
#
#    validVotesPercentage   Votes  Hondt  FinalMandates
# 0                 40.22  147993     94            106
# 1                 34.95  128624     81             77
# 2                  7.15   26307     16             19

# %%
df['Party'].unique()
# Out:
# array(['PS', 'PPD/PSD', 'B.E.', 'CDS-PP', 'PCP-PEV', 'PAN', 'CH',
#        'R.I.R.', 'PCTP/MRPP', 'A', 'L', 'IL', 'JPP', 'NC', 'PDR', 'PNR',
#        'PURP', 'PPM', 'MPT', 'PTP', 'MAS'], dtype=object)

# %%
#df["territoryName"] = df['territoryName'].astype(str)

#df['territoryName'] = df['territoryName'].astype(pd.StringDtype())


#df['Party'] = df['Party'].astype(pd.StringDtype())

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# FinalMandates                 int64
# dtype: object

# %% [markdown]
# #### Univariate Analysis

# %%
col=[]
value=[]

table=pd.DataFrame([])
for i in df.columns:
    col.append(i)
    value.append(df[i].nunique())

table['col_name']=col
table['values']=value

table
# Out:
#                     col_name  values
# 0                TimeElapsed      54
# 1                       time      54
# 2              territoryName      21
# 3              totalMandates      62
# 4          availableMandates      69
# 5                numParishes      20
# 6        numParishesApproved     219
# 7                 blankVotes     329
# 8       blankVotesPercentage     146
# 9                  nullVotes     331
# 10       nullVotesPercentage     107
# 11          votersPercentage     282
# 12          subscribedVoters     335
# 13               totalVoters     336
# 14            pre.blankVotes     323
# 15  pre.blankVotesPercentage     130
# 16             pre.nullVotes     329
# 17   pre.nullVotesPercentage      90
# 18      pre.votersPercentage     278
# 19      pre.subscribedVoters     331
# 20           pre.totalVoters     331
# 21                     Party      21
# 22                  Mandates      67
# 23                Percentage    1363
# 24      validVotesPercentage    1387
# 25                     Votes    4029
# 26                     Hondt      41
# 27             FinalMandates      17

# %% [markdown]
# Observations
# 1. There are 4029 unique votes, 1387 valid votes percentage, 1363 percentage values.

# %% [markdown]
# Attribute Information:
#
# TimeElapsed (Numeric): Time (minutes) passed since the first data acquisition
# time (timestamp): Date and time of the data acquisition
# territoryName (string): Short name of the location (district or nation-wide)
# totalMandates (numeric): MP's elected at the moment
# availableMandates (numeric): MP's left to elect at the moment
# numParishes (numeric): Total number of parishes in this location
# numParishesApproved (numeric): Number of parishes approved in this location
# blankVotes (numeric): Number of blank votes
# blankVotesPercentage (numeric): Percentage of blank votes
# nullVotes (numeric): Number of null votes
# nullVotesPercentage (numeric): Percentage of null votes
# votersPercentage (numeric): Percentage of voters
# subscribedVoters (numeric): Number of subscribed voters in the location
# totalVoters (numeric): Percentage of blank votes
# pre.blankVotes (numeric): Number of blank votes (previous election)
# pre.blankVotesPercentage (numeric): Percentage of blank votes (previous election)
# pre.nullVotes (numeric): Number of null votes (previous election)
# pre.nullVotesPercentage (numeric): Percentage of null votes (previous election)
# pre.votersPercentage (numeric): Percentage of voters (previous election)
# pre.subscribedVoters (numeric): Number of subscribed voters in the location (previous election)
# pre.totalVoters (numeric): Percentage of blank votes (previous election)
# Party (string): Political Party
# Mandates (numeric): MP's elected at the moment for the party in a given district
# Percentage (numeric): Percentage of votes in a party
# validVotesPercentage (numeric): Percentage of valid votes in a party
# Votes (numeric): Percentage of party votes
# Hondt (numeric): Number of MP's according to the distribution of votes now
# FinalMandates (numeric): Target: final number of elected MP's in a district/national-level

# %% [markdown]
# #### Univariate Analysis

# %%
df.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4BD73C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4B1A688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4E6F308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4CA9448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C5A58508>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000239C5A905C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C5AC8708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C5B01808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C5B0D3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239CF474588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000239CF4D8B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239CF50FBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239CF549D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239CF582E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239CF5B9F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000239CF5F6088>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4DE4188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4F88AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C51300C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C415D2C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000239CAFE15C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C529A708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4E20B48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C4FA9788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000239C58A0248>]],
#       dtype=object)

# %% [markdown]
# Observations
# 1. Few columns are symmetric.
# 2. Few columns are not symmetric which needs to be treated later.

# %%
for i in ['TimeElapsed', 'totalMandates','availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
       'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
       'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
       'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
       'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
       'Hondt', 'FinalMandates']:
    plt.figure(figsize=(20,15))
    plt.subplot(5,5,5)
    sns.boxplot(df[i])

# %%
# There are many outliers in the columns which needs to be removed later

# %% [markdown]
# #### Bivariate Analysis

# %%
for i in ['TimeElapsed','availableMandates', 'totalMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
       'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
       'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
       'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
       'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
       'Hondt']:
    plt.figure(figsize=(20,15))
    plt.subplot(5,5,5)
    sns.scatterplot(x=df[i], y='FinalMandates', data=df)

# %% [markdown]
# Observations
# 1. Mandates, Votes and Handt have positive correlation with the target to some extent, However, the linear relationship is not clear and not well established.
# 2. No other values show any positive correlation with the target.

# %%
df.corr()
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# pre.blankVotes               0.195734       0.973357           0.383877
# pre.blankVotesPercentage     0.093739       0.034774          -0.008966
# pre.nullVotes                0.189902       0.969992           0.399074
# pre.nullVotesPercentage     -0.106054      -0.132143          -0.044174
# pre.votersPercentage         0.054761       0.151927           0.080524
# pre.subscribedVoters         0.193160       0.972976           0.391272
# pre.totalVoters              0.196667       0.975404           0.383089
# Mandates                     0.090190       0.336989           0.072320
# Percentage                   0.000767      -0.010171          -0.011083
# validVotesPercentage         0.000526      -0.010474          -0.011052
# Votes                        0.082417       0.395617           0.152348
# Hondt                       -0.001100       0.288420           0.291310
# FinalMandates               -0.001007       0.264117           0.266764
#
#                           numParishes  numParishesApproved  blankVotes  \
# TimeElapsed                 -0.001944             0.100432    0.192350
# totalMandates                0.765877             0.873415    0.969988
# availableMandates            0.745472             0.562719    0.390638
# numParishes                  1.000000             0.954092    0.861279
# numParishesApproved          0.954092             1.000000    0.951265
# blankVotes                   0.861279             0.951265    1.000000
# blankVotesPercentage         0.032013             0.035153    0.038503
# nullVotes                    0.870240             0.956142    0.998781
# nullVotesPercentage          0.013209            -0.037416   -0.150894
# votersPercentage             0.073855             0.081157    0.183970
# subscribedVoters             0.856855             0.946191    0.998297
# totalVoters                  0.850881             0.940941    0.997951
# pre.blankVotes               0.856779             0.947190    0.999657
# pre.blankVotesPercentage     0.036461             0.050378    0.072183
# pre.nullVotes                0.864837             0.951899    0.997490
# pre.nullVotesPercentage     -0.058017            -0.073301   -0.150275
# pre.votersPercentage         0.026407             0.042180    0.161642
# pre.subscribedVoters         0.860782             0.949110    0.998487
# pre.totalVoters              0.853779             0.943147    0.998178
# Mandates                     0.257365             0.293795    0.326630
# Percentage                  -0.010770            -0.009840   -0.011883
# validVotesPercentage        -0.010624            -0.009767   -0.012002
# Votes                        0.343593             0.380311    0.404003
# Hondt                        0.359283             0.340901    0.322780
# FinalMandates                0.329009             0.312177    0.295583
#
#                           blankVotesPercentage  nullVotes  \
# TimeElapsed                           0.034343   0.185784
# totalMandates                        -0.003149   0.967294
# availableMandates                    -0.002806   0.407366
# numParishes                           0.032013   0.870240
# numParishesApproved                   0.035153   0.956142
# blankVotes                            0.038503   0.998781
# blankVotesPercentage                  1.000000   0.006615
# nullVotes                             0.006615   1.000000
# nullVotesPercentage                   0.094047  -0.136296
# votersPercentage                     -0.190778   0.181411
# subscribedVoters                      0.001598   0.998988
# totalVoters                          -0.002062   0.998405
# pre.blankVotes                        0.030061   0.998883
# pre.blankVotesPercentage              0.959142   0.041317
# pre.nullVotes                        -0.006067   0.999298
# pre.nullVotesPercentage              -0.307544  -0.125639
# pre.votersPercentage                 -0.105314   0.154965
# pre.subscribedVoters                  0.002821   0.999296
# pre.totalVoters                      -0.000069   0.998706
# Mandates                             -0.000926   0.325711
# Percentage                           -0.006258  -0.011602
# validVotesPercentage                 -0.002076  -0.011820
# Votes                                -0.001486   0.404195
# Hondt                                -0.001305   0.326144
# FinalMandates                        -0.001195   0.298663
#
#                           nullVotesPercentage  votersPercentage  \
# TimeElapsed                         -0.225021          0.029698
# totalMandates                       -0.165132          0.171317
# availableMandates                    0.029915          0.112293
# numParishes                          0.013209          0.073855
# numParishesApproved                 -0.037416          0.081157
# blankVotes                          -0.150894          0.183970
# blankVotesPercentage                 0.094047         -0.190778
# nullVotes                           -0.136296          0.181411
# nullVotesPercentage                  1.000000         -0.108855
# votersPercentage                    -0.108855          1.000000
# subscribedVoters                    -0.157263          0.173603
# totalVoters                         -0.161816          0.190476
# pre.blankVotes                      -0.152234          0.181595
# pre.blankVotesPercentage             0.100924         -0.144312
# pre.nullVotes                       -0.141809          0.170285
# pre.nullVotesPercentage              0.497749         -0.278275
# pre.votersPercentage                -0.233688          0.909825
# pre.subscribedVoters                -0.153891          0.172542
# pre.totalVoters                     -0.159566          0.186834
# Mandates                            -0.056254          0.056553
# Percentage                           0.003301         -0.019836
# validVotesPercentage                 0.005441         -0.020966
# Votes                               -0.066526          0.076377
# Hondt                               -0.032388          0.066665
# FinalMandates                       -0.029659          0.061048
#
#                           subscribedVoters  totalVoters  pre.blankVotes  \
# TimeElapsed                       0.195487     0.198243        0.195734
# totalMandates                     0.974407     0.976336        0.973357
# availableMandates                 0.385828     0.379093        0.383877
# numParishes                       0.856855     0.850881        0.856779
# numParishesApproved               0.946191     0.940941        0.947190
# blankVotes                        0.998297     0.997951        0.999657
# blankVotesPercentage              0.001598    -0.002062        0.030061
# nullVotes                         0.998988     0.998405        0.998883
# nullVotesPercentage              -0.157263    -0.161816       -0.152234
# votersPercentage                  0.173603     0.190476        0.181595
# subscribedVoters                  1.000000     0.999695        0.999145
# totalVoters                       0.999695     1.000000        0.998888
# pre.blankVotes                    0.999145     0.998888        1.000000
# pre.blankVotesPercentage          0.036789     0.033814        0.066297
# pre.nullVotes                     0.999323     0.998554        0.998383
# pre.nullVotesPercentage          -0.133139    -0.139684       -0.144753
# pre.votersPercentage              0.152401     0.167300        0.160625
# pre.subscribedVoters              0.999954     0.999515        0.999203
# pre.totalVoters                   0.999841     0.999952        0.999085
# Mandates                          0.328197     0.328836        0.327807
# Percentage                       -0.011276    -0.011560       -0.011719
# validVotesPercentage             -0.011548    -0.011856       -0.011872
# Votes                             0.404861     0.404996        0.404458
# Hondt                             0.322750     0.321587        0.321997
# FinalMandates                     0.295555     0.294490        0.294866
#
#                           pre.blankVotesPercentage  pre.nullVotes  \
# TimeElapsed                               0.093739       0.189902
# totalMandates                             0.034774       0.969992
# availableMandates                        -0.008966       0.399074
# numParishes                               0.036461       0.864837
# numParishesApproved                       0.050378       0.951899
# blankVotes                                0.072183       0.997490
# blankVotesPercentage                      0.959142      -0.006067
# nullVotes                                 0.041317       0.999298
# nullVotesPercentage                       0.100924      -0.141809
# votersPercentage                         -0.144312       0.170285
# subscribedVoters                          0.036789       0.999323
# totalVoters                               0.033814       0.998554
# pre.blankVotes                            0.066297       0.998383
# pre.blankVotesPercentage                  1.000000       0.031007
# pre.nullVotes                             0.031007       1.000000
# pre.nullVotesPercentage                  -0.215877      -0.109795
# pre.votersPercentage                     -0.106425       0.145249
# pre.subscribedVoters                      0.037737       0.999499
# pre.totalVoters                           0.035404       0.998879
# Mandates                                  0.011932       0.326680
# Percentage                               -0.008944      -0.011332
# validVotesPercentage                     -0.004922      -0.011607
# Votes                                     0.013206       0.404354
# Hondt                                     0.006242       0.324854
# FinalMandates                             0.005716       0.297482
#
#                           pre.nullVotesPercentage  pre.votersPercentage  \
# TimeElapsed                             -0.106054              0.054761
# totalMandates                           -0.132143              0.151927
# availableMandates                       -0.044174              0.080524
# numParishes                             -0.058017              0.026407
# numParishesApproved                     -0.073301              0.042180
# blankVotes                              -0.150275              0.161642
# blankVotesPercentage                    -0.307544             -0.105314
# nullVotes                               -0.125639              0.154965
# nullVotesPercentage                      0.497749             -0.233688
# votersPercentage                        -0.278275              0.909825
# subscribedVoters                        -0.133139              0.152401
# totalVoters                             -0.139684              0.167300
# pre.blankVotes                          -0.144753              0.160625
# pre.blankVotesPercentage                -0.215877             -0.106425
# pre.nullVotes                           -0.109795              0.145249
# pre.nullVotesPercentage                  1.000000             -0.499374
# pre.votersPercentage                    -0.499374              1.000000
# pre.subscribedVoters                    -0.131705              0.150632
# pre.totalVoters                         -0.139431              0.165287
# Mandates                                -0.044964              0.050533
# Percentage                               0.000391             -0.012054
# validVotesPercentage                     0.000158             -0.013078
# Votes                                   -0.057086              0.067619
# Hondt                                   -0.042245              0.055092
# FinalMandates                           -0.038686              0.050450
#
#                           pre.subscribedVoters  pre.totalVoters  Mandates  \
# TimeElapsed                           0.193160         0.196667  0.090190
# totalMandates                         0.972976         0.975404  0.336989
# availableMandates                     0.391272         0.383089  0.072320
# numParishes                           0.860782         0.853779  0.257365
# numParishesApproved                   0.949110         0.943147  0.293795
# blankVotes                            0.998487         0.998178  0.326630
# blankVotesPercentage                  0.002821        -0.000069 -0.000926
# nullVotes                             0.999296         0.998706  0.325711
# nullVotesPercentage                  -0.153891        -0.159566 -0.056254
# votersPercentage                      0.172542         0.186834  0.056553
# subscribedVoters                      0.999954         0.999841  0.328197
# totalVoters                           0.999515         0.999952  0.328836
# pre.blankVotes                        0.999203         0.999085  0.327807
# pre.blankVotesPercentage              0.037737         0.035404  0.011932
# pre.nullVotes                         0.999499         0.998879  0.326680
# pre.nullVotesPercentage              -0.131705        -0.139431 -0.044964
# pre.votersPercentage                  0.150632         0.165287  0.050533
# pre.subscribedVoters                  1.000000         0.999725  0.327703
# pre.totalVoters                       0.999725         1.000000  0.328527
# Mandates                              0.327703         0.328527  1.000000
# Percentage                           -0.011279        -0.011453  0.312402
# validVotesPercentage                 -0.011540        -0.011737  0.311762
# Votes                                 0.404765         0.404976  0.972310
# Hondt                                 0.323704         0.322329  0.791960
# FinalMandates                         0.296428         0.295169  0.814370
#
#                           Percentage  validVotesPercentage     Votes  \
# TimeElapsed                 0.000767              0.000526  0.082417
# totalMandates              -0.010171             -0.010474  0.395617
# availableMandates          -0.011083             -0.011052  0.152348
# numParishes                -0.010770             -0.010624  0.343593
# numParishesApproved        -0.009840             -0.009767  0.380311
# blankVotes                 -0.011883             -0.012002  0.404003
# blankVotesPercentage       -0.006258             -0.002076 -0.001486
# nullVotes                  -0.011602             -0.011820  0.404195
# nullVotesPercentage         0.003301              0.005441 -0.066526
# votersPercentage           -0.019836             -0.020966  0.076377
# subscribedVoters           -0.011276             -0.011548  0.404861
# totalVoters                -0.011560             -0.011856  0.404996
# pre.blankVotes             -0.011719             -0.011872  0.404458
# pre.blankVotesPercentage   -0.008944             -0.004922  0.013206
# pre.nullVotes              -0.011332             -0.011607  0.404354
# pre.nullVotesPercentage     0.000391              0.000158 -0.057086
# pre.votersPercentage       -0.012054             -0.013078  0.067619
# pre.subscribedVoters       -0.011279             -0.011540  0.404765
# pre.totalVoters            -0.011453             -0.011737  0.404976
# Mandates                    0.312402              0.311762  0.972310
# Percentage                  1.000000              0.999944  0.327706
# validVotesPercentage        0.999944              1.000000  0.327054
# Votes                       0.327706              0.327054  1.000000
# Hondt                       0.401192              0.400857  0.872658
# FinalMandates               0.383086              0.382744  0.882502
#
#                              Hondt  FinalMandates
# TimeElapsed              -0.001100      -0.001007
# totalMandates             0.288420       0.264117
# availableMandates         0.291310       0.266764
# numParishes               0.359283       0.329009
# numParishesApproved       0.340901       0.312177
# blankVotes                0.322780       0.295583
# blankVotesPercentage     -0.001305      -0.001195
# nullVotes                 0.326144       0.298663
# nullVotesPercentage      -0.032388      -0.029659
# votersPercentage          0.066665       0.061048
# subscribedVoters          0.322750       0.295555
# totalVoters               0.321587       0.294490
# pre.blankVotes            0.321997       0.294866
# pre.blankVotesPercentage  0.006242       0.005716
# pre.nullVotes             0.324854       0.297482
# pre.nullVotesPercentage  -0.042245      -0.038686
# pre.votersPercentage      0.055092       0.050450
# pre.subscribedVoters      0.323704       0.296428
# pre.totalVoters           0.322329       0.295169
# Mandates                  0.791960       0.814370
# Percentage                0.401192       0.383086
# validVotesPercentage      0.400857       0.382744
# Votes                     0.872658       0.882502
# Hondt                     1.000000       0.994480
# FinalMandates             0.994480       1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# Observations
# 1. We can observe from the map that many columns are positively correlated with each other however, with the target column positive correlation is less.
# 2. The percentage of votes like blank votes, null votes etc show negative correlation with variables.

# %%
df.groupby('Party').sum().sort_values(by='FinalMandates',ascending=False)
# Out:
#            TimeElapsed  totalMandates  availableMandates  numParishes  \
# Party
# PS              150150          12239              12134       332844
# PPD/PSD         150150          12239              12134       332844
# B.E.            150150          12239              12134       332844
# PCP-PEV         150150          12239              12134       332844
# CDS-PP          150150          12239              12134       332844
# PAN             150150          12239              12134       332844
# CH              150150          12239              12134       332844
# IL              150150          12239              12134       332844
# L               150150          12239              12134       332844
# PNR             150150          12239              12134       332844
# PURP            128790          11782              11924       310824
# PTP             135840          11787              11830       313836
# PPM             142995          12169              12096       329118
# A               150150          12239              12134       332844
# PDR             150150          12239              12134       332844
# PCTP/MRPP       150150          12239              12134       332844
# NC              128790          11875              11939       315306
# MPT             135840          11974              11967       310002
# MAS              57135           9689              10526       230676
# JPP              64395           9521               8839       250182
# R.I.R.          135945          11960              12016       321462
#
#            numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# Party
# PS                      280841     9395287               2950.69    6518912
# PPD/PSD                 280841     9395287               2950.69    6518912
# B.E.                    280841     9395287               2950.69    6518912
# PCP-PEV                 280841     9395287               2950.69    6518912
# CDS-PP                  280841     9395287               2950.69    6518912
# PAN                     280841     9395287               2950.69    6518912
# CH                      280841     9395287               2950.69    6518912
# IL                      280841     9395287               2950.69    6518912
# L                       280841     9395287               2950.69    6518912
# PNR                     280841     9395287               2950.69    6518912
# PURP                    261219     9075922               2491.94    6306658
# PTP                     264399     9022425               2645.37    6255351
# PPM                     277619     9343897               2830.80    6475614
# A                       280841     9395287               2950.69    6518912
# PDR                     280841     9395287               2950.69    6518912
# PCTP/MRPP               280841     9395287               2950.69    6518912
# NC                      265085     9085494               2473.44    6318895
# MPT                     260381     9239874               2722.14    6349108
# MAS                     190635     7610545               1289.04    5126470
# JPP                     209777     7390703               1317.22    5069877
# R.I.R.                  270728     9175477               2611.00    6414823
#
#            nullVotesPercentage  votersPercentage  subscribedVoters  \
# Party
# PS                     2215.39          58346.06         665766133
# PPD/PSD                2215.39          58346.06         665766133
# B.E.                   2215.39          58346.06         665766133
# PCP-PEV                2215.39          58346.06         665766133
# CDS-PP                 2215.39          58346.06         665766133
# PAN                    2215.39          58346.06         665766133
# CH                     2215.39          58346.06         665766133
# IL                     2215.39          58346.06         665766133
# L                      2215.39          58346.06         665766133
# PNR                    2215.39          58346.06         665766133
# PURP                   1914.87          51366.84         641214809
# PTP                    1970.50          53055.29         640917577
# PPM                    2111.53          55441.59         661544167
# A                      2215.39          58346.06         665766133
# PDR                    2215.39          58346.06         665766133
# PCTP/MRPP              2215.39          58346.06         665766133
# NC                     1901.60          50762.07         644829789
# MPT                    1960.55          53507.43         649799643
# MAS                     798.01          22609.34         527778983
# JPP                     947.48          26037.72         509674239
# R.I.R.                 2047.51          53804.63         651058896
#
#            totalVoters  pre.blankVotes  pre.blankVotesPercentage  \
# Party
# PS           359000985         8057433                   2329.12
# PPD/PSD      359000985         8057433                   2329.12
# B.E.         359000985         8057433                   2329.12
# PCP-PEV      359000985         8057433                   2329.12
# CDS-PP       359000985         8057433                   2329.12
# PAN          359000985         8057433                   2329.12
# CH           359000985         8057433                   2329.12
# IL           359000985         8057433                   2329.12
# L            359000985         8057433                   2329.12
# PNR          359000985         8057433                   2329.12
# PURP         348267019         7794818                   1994.80
# PTP          346548900         7739254                   2096.15
# PPM          356754828         8008297                   2228.60
# A            359000985         8057433                   2329.12
# PDR          359000985         8057433                   2329.12
# PCTP/MRPP    359000985         8057433                   2329.12
# NC           349225040         7792190                   1965.26
# MPT          351800061         7921713                   2146.56
# MAS          288573666         6485911                    989.13
# JPP          277665023         6291719                   1058.51
# R.I.R.       352732438         7879443                   2086.40
#
#            pre.nullVotes  pre.nullVotesPercentage  pre.votersPercentage  \
# Party
# PS               6276852                  2003.32              61324.34
# PPD/PSD          6276852                  2003.32              61324.34
# B.E.             6276852                  2003.32              61324.34
# PCP-PEV          6276852                  2003.32              61324.34
# CDS-PP           6276852                  2003.32              61324.34
# PAN              6276852                  2003.32              61324.34
# CH               6276852                  2003.32              61324.34
# IL               6276852                  2003.32              61324.34
# L                6276852                  2003.32              61324.34
# PNR              6276852                  2003.32              61324.34
# PURP             6072778                  1743.18              53674.26
# PTP              6044083                  1810.30              55750.28
# PPM              6237971                  1924.38              58147.46
# A                6276852                  2003.32              61324.34
# PDR              6276852                  2003.32              61324.34
# PCTP/MRPP        6276852                  2003.32              61324.34
# NC               6074701                  1727.95              53107.81
# MPT              6127507                  1797.39              56224.95
# MAS              4871060                   692.67              23744.41
# JPP              4821709                   889.20              26499.86
# R.I.R.           6161451                  1840.95              56246.61
#
#            pre.subscribedVoters  pre.totalVoters  Mandates  Percentage  \
# Party
# PS                    676907658        380938145      6068    42490.98
# PPD/PSD               676907658        380938145      4444    32768.47
# B.E.                  676907658        380938145       858     9611.44
# PCP-PEV               676907658        380938145       508     7534.69
# CDS-PP                676907658        380938145       204     5023.66
# PAN                   676907658        380938145       123     2734.94
# CH                    676907658        380938145         3     1465.35
# IL                    676907658        380938145        28      810.38
# L                     676907658        380938145         3      810.07
# PNR                   676907658        380938145         0      301.71
# PURP                  651664116        368843946         0      233.36
# PTP                   651101973        367337150         0      195.23
# PPM                   672471065        378348423         0      194.80
# A                     676907658        380938145         0      719.16
# PDR                   676907658        380938145         0      214.79
# PCTP/MRPP             676907658        380938145         0      840.68
# NC                    655255396        369908462         0      226.41
# MPT                   660176217        372985641         0      238.30
# MAS                   533865122        304569880         0       40.63
# JPP                   518690481        292545534         0      329.04
# R.I.R.                661970245        373775892         0      748.80
#
#            validVotesPercentage      Votes  Hondt  FinalMandates
# Party
# PS                     44532.04  132365510  10715          11427
# PPD/PSD                34372.26  103212955   8221           8302
# B.E.                   10076.67   33526986   2083           2052
# PCP-PEV                 7868.97   21873464   1354           1296
# CDS-PP                  5268.54   15564810    843            540
# PAN                     2867.11   10903515    519            432
# CH                      1535.24    4499005    183            108
# IL                       849.47    3925509    143            108
# L                        849.43    3427336    119            108
# PNR                      315.59    1023888      0              0
# PURP                     243.43     734948      0              0
# PTP                      204.55     556944      0              0
# PPM                      204.38     561822      0              0
# A                        754.24    2580816     54              0
# PDR                      225.26     678813      0              0
# PCTP/MRPP                879.28    2435776     54              0
# NC                       237.67     775637      0              0
# MPT                      251.03     809221      0              0
# MAS                       42.73     199878      0              0
# JPP                      338.65     819092      0              0
# R.I.R.                   783.59    2610861     85              0

# %% [markdown]
# Observations
# 1. The party PS has obtained more Final mandates, followed by PPD/SSD and later by BE.
# 2. We can observe that apart from Mandates, Party, Percentage validVotesPercentage, Votes, Hondt and FinalMandates, all other columns are almost common for all parties. There might be slight difference depending on the no. of places the party has contested.
# 3. Since we have used sum as aggregating function, percentage etc are showing huge values.

# %% [markdown]
# ### Observation about model building - whether regression or classification
# If we observe, we can see that the target final mandate is not showing positive linear relationship with any variables as the final mandate depends on the parties. As party which has won will have more mandates.
#
# So the problem is not regression, but classification since, the relationship with the target is not linear.

# %%
# Lets check the unique values in the target column
df['FinalMandates'].value_counts()
# Out:
# 0      17823
# 1       1134
# 2        695
# 3        641
# 4        378
# 5        270
# 8        108
# 12       108
# 7         54
# 6         54
# 77        54
# 20        54
# 19        54
# 9         54
# 106       54
# 17        54
# 15        54
# Name: FinalMandates, dtype: int64

# %% [markdown]
# Observations
# 1. There are 17823 values have zero mandates, followed by 1134 one mandate and 54 values had 106 highest mandate.
#
# We can convert them into bins of 0-5, 5-10, 11-15, 16-20, 75-110 after removing outliers.

# %% [markdown]
# ##### Label Encoder

# %%
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# Hondt                         int64
# FinalMandates                 int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='O':
        df[i]=lb.fit_transform(df[i])

# %%
df.head(2)
# Out:
#    TimeElapsed  time  territoryName  totalMandates  availableMandates  \
# 0            0     0             16              0                226
# 1            0     0             16              0                226
#
#    numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 0         3092                 1081        9652                   2.5
# 1         3092                 1081        9652                   2.5
#
#    nullVotes  nullVotesPercentage  votersPercentage  subscribedVoters  \
# 0       8874                  2.3             51.36            752529
# 1       8874                  2.3             51.36            752529
#
#    totalVoters  pre.blankVotes  pre.blankVotesPercentage  pre.nullVotes  \
# 0       386497            8317                      1.94           8171
# 1       386497            8317                      1.94           8171
#
#    pre.nullVotesPercentage  pre.votersPercentage  pre.subscribedVoters  \
# 0                     1.91                 52.66                813743
# 1                     1.91                 52.66                813743
#
#    pre.totalVoters  Party  Mandates  Percentage  validVotesPercentage   Votes  \
# 0           428546     17         0       38.29                 40.22  147993
# 1           428546     15         0       33.28                 34.95  128624
#
#    Hondt  FinalMandates
# 0     94            106
# 1     81             77

# %% [markdown]
# ##### removing outliers

# %%
from scipy.stats import zscore
print("The shape of the dataframe before removing outliers is", df.shape)
z=np.abs(zscore(df))
df1=df[(z<3).all(axis=1)]
print("The shape of the dataframe before removing outliers is", df1.shape)
# Out:
# The shape of the dataframe before removing outliers is (21643, 28)
# The shape of the dataframe before removing outliers is (18333, 28)

# %%
# creating bins for the target data
bins=[0,5,10,15,20,np.inf]
names=['0-5','5-10','10-15','15-20','75-110']
df1['Finalmandate_range']=pd.cut(df1['FinalMandates'],bins,labels=names)
df1['Finalmandate_range']
# few missing values Nan are created with needs to treated later
# Out:
# 22       5-10
# 23        0-5
# 24        0-5
# 25        NaN
# 26        NaN
#          ...
# 21638     NaN
# 21639     NaN
# 21640     NaN
# 21641     NaN
# 21642     NaN
# Name: Finalmandate_range, Length: 18333, dtype: category
# Categories (5, object): [0-5 < 5-10 < 10-15 < 15-20 < 75-110]

# %%
df1['FinalMandates'].value_counts()
# note that the no. of counts of '0' are 16154
# Out:
# 0     16154
# 1       900
# 3       413
# 2       316
# 4       206
# 5        93
# 12       54
# 7        54
# 8        46
# 6        45
# 15       43
# 20        9
# Name: FinalMandates, dtype: int64

# %%
df1['Finalmandate_range'].value_counts()
# Out:
# 0-5       1928
# 5-10       145
# 10-15       97
# 15-20        9
# 75-110       0
# Name: Finalmandate_range, dtype: int64

# %%
df1['Finalmandate_range'].isnull().sum()
# note that the null value counts is 16154. With reference with the above, we can understand that '0' is replaced with Nan.
#.... so we need to reclassify Nan into 0-5 group manually
# Out:
# 16154

# %%
# classifying the null values into proper group 0-5
df1['Finalmandate_range']=df1['Finalmandate_range'].fillna('0-5')
df1['Finalmandate_range'].value_counts()
# Out:
# 0-5       18082
# 5-10        145
# 10-15        97
# 15-20         9
# 75-110        0
# Name: Finalmandate_range, dtype: int64

# %% [markdown]
# #### splitting the data into input and output variables
# The data will be split into input and output variables.

# %%
df1.head()
# Out:
#     TimeElapsed  time  territoryName  totalMandates  availableMandates  \
# 22            0     0              0              0                 16
# 23            0     0              0              0                 16
# 24            0     0              0              0                 16
# 25            0     0              0              0                 16
# 26            0     0              0              0                 16
#
#     numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 22          147                   12         186                  2.92
# 23          147                   12         186                  2.92
# 24          147                   12         186                  2.92
# 25          147                   12         186                  2.92
# 26          147                   12         186                  2.92
#
#     nullVotes  nullVotesPercentage  votersPercentage  subscribedVoters  \
# 22        101                 1.59              53.3             11953
# 23        101                 1.59              53.3             11953
# 24        101                 1.59              53.3             11953
# 25        101                 1.59              53.3             11953
# 26        101                 1.59              53.3             11953
#
#     totalVoters  pre.blankVotes  pre.blankVotesPercentage  pre.nullVotes  \
# 22         6371             124                      1.82            111
# 23         6371             124                      1.82            111
# 24         6371             124                      1.82            111
# 25         6371             124                      1.82            111
# 26         6371             124                      1.82            111
#
#     pre.nullVotesPercentage  pre.votersPercentage  pre.subscribedVoters  \
# 22                     1.63                 54.56                 12511
# 23                     1.63                 54.56                 12511
# 24                     1.63                 54.56                 12511
# 25                     1.63                 54.56                 12511
# 26                     1.63                 54.56                 12511
#
#     pre.totalVoters  Party  Mandates  Percentage  validVotesPercentage  Votes  \
# 22             6826     17         0       34.33                 35.95   2187
# 23             6826      1         0        7.47                  7.82    476
# 24             6826      2         0        6.14                  6.43    391
# 25             6826     11         0        2.39                  2.50    152
# 26             6826     10         0        2.04                  2.14    130
#
#     Hondt  FinalMandates Finalmandate_range
# 22      7              7               5-10
# 23      1              2                0-5
# 24      1              1                0-5
# 25      0              0                0-5
# 26      0              0                0-5

# %%
x=df1.iloc[:,0:-1]
y=pd.DataFrame(df1.iloc[:,-1])
x.head()
# Out:
#     TimeElapsed  time  territoryName  totalMandates  availableMandates  \
# 22            0     0              0              0                 16
# 23            0     0              0              0                 16
# 24            0     0              0              0                 16
# 25            0     0              0              0                 16
# 26            0     0              0              0                 16
#
#     numParishes  numParishesApproved  blankVotes  blankVotesPercentage  \
# 22          147                   12         186                  2.92
# 23          147                   12         186                  2.92
# 24          147                   12         186                  2.92
# 25          147                   12         186                  2.92
# 26          147                   12         186                  2.92
#
#     nullVotes  nullVotesPercentage  votersPercentage  subscribedVoters  \
# 22        101                 1.59              53.3             11953
# 23        101                 1.59              53.3             11953
# 24        101                 1.59              53.3             11953
# 25        101                 1.59              53.3             11953
# 26        101                 1.59              53.3             11953
#
#     totalVoters  pre.blankVotes  pre.blankVotesPercentage  pre.nullVotes  \
# 22         6371             124                      1.82            111
# 23         6371             124                      1.82            111
# 24         6371             124                      1.82            111
# 25         6371             124                      1.82            111
# 26         6371             124                      1.82            111
#
#     pre.nullVotesPercentage  pre.votersPercentage  pre.subscribedVoters  \
# 22                     1.63                 54.56                 12511
# 23                     1.63                 54.56                 12511
# 24                     1.63                 54.56                 12511
# 25                     1.63                 54.56                 12511
# 26                     1.63                 54.56                 12511
#
#     pre.totalVoters  Party  Mandates  Percentage  validVotesPercentage  Votes  \
# 22             6826     17         0       34.33                 35.95   2187
# 23             6826      1         0        7.47                  7.82    476
# 24             6826      2         0        6.14                  6.43    391
# 25             6826     11         0        2.39                  2.50    152
# 26             6826     10         0        2.04                  2.14    130
#
#     Hondt  FinalMandates
# 22      7              7
# 23      1              2
# 24      1              1
# 25      0              0
# 26      0              0

# %%
y.head()
# Out:
#    Finalmandate_range
# 22               5-10
# 23                0-5
# 24                0-5
# 25                0-5
# 26                0-5

# %% [markdown]
# #### Checking the skewness in the datasets

# %%
x.skew()
# Out:
# TimeElapsed                -0.024110
# time                       -0.024110
# territoryName               0.034073
# totalMandates               2.542453
# availableMandates           2.593527
# numParishes                 0.585363
# numParishesApproved         0.619329
# blankVotes                  1.800122
# blankVotesPercentage       -0.844508
# nullVotes                   2.103352
# nullVotesPercentage         0.564426
# votersPercentage           -0.392023
# subscribedVoters            2.407541
# totalVoters                 2.468630
# pre.blankVotes              2.034860
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes               2.340000
# pre.nullVotesPercentage     1.033803
# pre.votersPercentage       -0.514215
# pre.subscribedVoters        2.370988
# pre.totalVoters             2.468950
# Party                       0.009657
# Mandates                    7.177093
# Percentage                  3.373567
# validVotesPercentage        3.383145
# Votes                       7.310058
# Hondt                       7.012845
# FinalMandates               6.746120
# dtype: float64

# %%
#using log1p method to remove the skewness
for i in x.columns:
    if x.skew()[i]>0.55:
        x[i]=np.log1p(x[i])

# %%
x.skew()
# Out:
# TimeElapsed                -0.024110
# time                       -0.024110
# territoryName               0.034073
# totalMandates               0.020702
# availableMandates           0.503375
# numParishes                -0.138265
# numParishesApproved        -1.099103
# blankVotes                 -0.592756
# blankVotesPercentage       -0.844508
# nullVotes                  -0.880145
# nullVotesPercentage         0.329675
# votersPercentage           -0.392023
# subscribedVoters           -0.772107
# totalVoters                -0.647681
# pre.blankVotes             -0.642916
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes              -0.937998
# pre.nullVotesPercentage     0.628444
# pre.votersPercentage       -0.514215
# pre.subscribedVoters       -0.802802
# pre.totalVoters            -0.670218
# Party                       0.009657
# Mandates                    4.479200
# Percentage                  1.565493
# validVotesPercentage        1.550088
# Votes                       0.268973
# Hondt                       3.488567
# FinalMandates               3.368168
# dtype: float64

# %%
#using sqrt method to remove the skewness
for i in x.columns:
    if x.skew()[i]>0.55:
        x[i]=np.sqrt(x[i])

# %%
x.skew()
#skewness is reduced to a large extent
# Out:
# TimeElapsed                -0.024110
# time                       -0.024110
# territoryName               0.034073
# totalMandates               0.020702
# availableMandates           0.503375
# numParishes                -0.138265
# numParishesApproved        -1.099103
# blankVotes                 -0.592756
# blankVotesPercentage       -0.844508
# nullVotes                  -0.880145
# nullVotesPercentage         0.329675
# votersPercentage           -0.392023
# subscribedVoters           -0.772107
# totalVoters                -0.647681
# pre.blankVotes             -0.642916
# pre.blankVotesPercentage   -0.410446
# pre.nullVotes              -0.937998
# pre.nullVotesPercentage     0.441833
# pre.votersPercentage       -0.514215
# pre.subscribedVoters       -0.802802
# pre.totalVoters            -0.670218
# Party                       0.009657
# Mandates                    3.674757
# Percentage                  0.932295
# validVotesPercentage        0.921731
# Votes                       0.268973
# Hondt                       2.706402
# FinalMandates               2.617752
# dtype: float64

# %%
#Scaling the data

# %%
#We need to scale the data for normalising the input data and for the same we can use Minmaxscaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x))
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.752045 -1.752045 -1.741356 -1.454853  1.362509  0.168399 -2.386279
# 1 -1.752045 -1.752045 -1.741356 -1.454853  1.362509  0.168399 -2.386279
# 2 -1.752045 -1.752045 -1.741356 -1.454853  1.362509  0.168399 -2.386279
# 3 -1.752045 -1.752045 -1.741356 -1.454853  1.362509  0.168399 -2.386279
# 4 -1.752045 -1.752045 -1.741356 -1.454853  1.362509  0.168399 -2.386279
#
#           7         8         9        10       11        12        13  \
# 0 -1.995387  0.540356 -2.548819 -1.079287  0.18551 -2.374963 -2.316742
# 1 -1.995387  0.540356 -2.548819 -1.079287  0.18551 -2.374963 -2.316742
# 2 -1.995387  0.540356 -2.548819 -1.079287  0.18551 -2.374963 -2.316742
# 3 -1.995387  0.540356 -2.548819 -1.079287  0.18551 -2.374963 -2.316742
# 4 -1.995387  0.540356 -2.548819 -1.079287  0.18551 -2.374963 -2.316742
#
#          14       15        16        17        18        19        20  \
# 0 -2.268273 -0.45199 -2.471572 -0.312112 -0.133418 -2.407375 -2.386617
# 1 -2.268273 -0.45199 -2.471572 -0.312112 -0.133418 -2.407375 -2.386617
# 2 -2.268273 -0.45199 -2.471572 -0.312112 -0.133418 -2.407375 -2.386617
# 3 -2.268273 -0.45199 -2.471572 -0.312112 -0.133418 -2.407375 -2.386617
# 4 -2.268273 -0.45199 -2.471572 -0.312112 -0.133418 -2.407375 -2.386617
#
#          21        22        23        24        25        26        27
# 0  1.177919 -0.266426  2.505502  2.496241  0.519213  3.757070  3.687393
# 1 -1.435236 -0.266426  1.523805  1.522741 -0.260514  2.021925  2.582619
# 2 -1.271914 -0.266426  1.386464  1.386704 -0.360975  2.021925  1.977914
# 3  0.197986 -0.266426  0.702331  0.705693 -0.842575 -0.348328 -0.357277
# 4  0.034664 -0.266426  0.586135  0.591956 -0.922041 -0.348328 -0.357277

# %% [markdown]
# #### deriving the best random_state for splitting the data into train and test

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def max_acc_score(reg,x,y):
    max_acc_score=0
    for r_state in range(42,101):
        train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=r_state,test_size=0.20)
        reg.fit(train_x,train_y)
        pred=reg.predict(test_x)
        acc_score=accuracy_score(test_y,pred)
        if acc_score>max_acc_score:
            max_acc_score=acc_score
            final_r_state=r_state
    print("The max accuracy score ", max_acc_score, "is achieved at", final_r_state)
    return final_r_state

# %%
#Checking the DecisionTreeClassifier for the above (we cannot use logistic as it is not binary classification)
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

max_acc_score(dt,x,y)
# Out:
# The max accuracy score  1.0 is achieved at 42
# 42

# %%
#We need to finalise the train and test data
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=42,test_size=0.20)
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (14666, 28)
# (14666, 1)
# (3667, 28)
# (3667, 1)

# %% [markdown]
# We need to check the performance of other modules and their scores. For the same we need to use GridSearchCV to select best parameters for the models

# %% [markdown]
# ### GridSearchCV for selecting best parameters

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
kn=KNeighborsClassifier()
parameters={'n_neighbors':(5,10,15,20),'weights':('uniform','distance'),'algorithm':('auto','ball_tree','kd_tree','brute')}
gdkn=GridSearchCV(kn,parameters)
gdkn.fit(train_x,train_y)
gdkn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'uniform'}

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
parameters={'criterion':('gini','entropy'), 'splitter':('best','random')}
gddt=GridSearchCV(dt,parameters)
gddt.fit(train_x,train_y)
gddt.best_params_
# Out:
# {'criterion': 'gini', 'splitter': 'best'}

# %%
from sklearn.svm import SVC
sv=SVC()
parameters={'C':(1,10),'kernel':('linear','poly','rbf')}
gdsv=GridSearchCV(sv,parameters)
gdsv.fit(train_x,train_y)
gdsv.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
#After obtaining best parameters, we should now check the models

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score

score=[]
cv=[]


algorithms=[KNeighborsClassifier(algorithm='auto', n_neighbors= 5, weights='distance'), DecisionTreeClassifier(criterion= 'gini', splitter= 'best'), SVC(C=1, kernel='linear')]

for i in algorithms:
    print(i)
    i.fit(train_x,train_y)
    pred=i.predict(test_x)
    accscore=accuracy_score(test_y,pred)
    score.append(accscore)
    print("")
    print("The accuracy score is ", accscore)
    print("")
    cvscore=cross_val_score(i,x,y,cv=5,scoring='accuracy').mean()
    cv.append(cvscore)
    print("The cross val score is", cvscore)
    print()
    print(classification_report(test_y,pred))
    print()
    print(confusion_matrix(test_y,pred))
    print()
    print()
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='distance')
#
# The accuracy score is  1.0
#
# The cross val score is 0.9929097354785927
#
#               precision    recall  f1-score   support
#
#          0-5       1.00      1.00      1.00      3622
#        10-15       1.00      1.00      1.00        18
#        15-20       1.00      1.00      1.00         1
#         5-10       1.00      1.00      1.00        26
#
#     accuracy                           1.00      3667
#    macro avg       1.00      1.00      1.00      3667
# weighted avg       1.00      1.00      1.00      3667
#
#
# [[3622    0    0    0]
#  [   0   18    0    0]
#  [   0    0    1    0]
#  [   0    0    0   26]]
#
#
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
# The accuracy score is  1.0
#
# The cross val score is 0.9995091355331333
#
#               precision    recall  f1-score   support
#
#          0-5       1.00      1.00      1.00      3622
#        10-15       1.00      1.00      1.00        18
#        15-20       1.00      1.00      1.00         1
#         5-10       1.00      1.00      1.00        26
#
#     accuracy                           1.00      3667
#    macro avg       1.00      1.00      1.00      3667
# weighted avg       1.00      1.00      1.00      3667
#
#
# [[3622    0    0    0]
#  [   0   18    0    0]
#  [   0    0    1    0]
#  [   0    0    0   26]]
#
#
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
# The accuracy score is  1.0
#
# The cross val score is 0.9818925552222526
#
#               precision    recall  f1-score   support
#
#          0-5       1.00      1.00      1.00      3622
#        10-15       1.00      1.00      1.00        18
#        15-20       1.00      1.00      1.00         1
#         5-10       1.00      1.00      1.00        26
#
#     accuracy                           1.00      3667
#    macro avg       1.00      1.00      1.00      3667
# weighted avg       1.00      1.00      1.00      3667
#
#
# [[3622    0    0    0]
#  [   0   18    0    0]
#  [   0    0    1    0]
#  [   0    0    0   26]]

# %%
result=pd.DataFrame({'Model':[KNeighborsClassifier, DecisionTreeClassifier, SVC],'Accuracy_Score':score,'Cross_val_score':cv})
result
# Out:
#                                                Model  Accuracy_Score  \
# 0  <class 'sklearn.neighbors._classification.KNei...             1.0
# 1  <class 'sklearn.tree._classes.DecisionTreeClas...             1.0
# 2                 <class 'sklearn.svm._classes.SVC'>             1.0
#
#    Cross_val_score
# 0         0.992910
# 1         0.999509
# 2         0.981893

# %% [markdown]
# By comparing the above results, we can conclude that DecisionTree is the best model which is giving best results with good cross val score

# %%
#Let us finalise the DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion= 'gini', splitter= 'best')
dt.fit(train_x,train_y)
pred=dt.predict(test_x)
acc_score=accuracy_score(test_y,pred)
crossval=cross_val_score(dt,x,y,cv=5,scoring='accuracy').mean()
print("The accuracy score is", acc_score)
print("The cross validation score is", crossval)
pd.DataFrame(pred).to_csv("Project19_Election results_csv")
# Out:
# The accuracy score is 1.0
# The cross validation score is 0.9990728115625853

# %%
from sklearn.externals import joblib
joblib.dump(dt,'DecisionTreeClassifier.pkl')
# Out:
# ['DecisionTreeClassifier.pkl']
