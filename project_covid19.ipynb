# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import datetime as dt
import numpy as np

# %%
#importing main dataset
df=pd.read_csv('covid.csv',parse_dates=['Date'])

# %%
df.head()
# Out:
#         Date      Country  Confirmed  Recovered  Deaths
# 0 2020-01-22  Afghanistan          0          0       0
# 1 2020-01-22      Albania          0          0       0
# 2 2020-01-22      Algeria          0          0       0
# 3 2020-01-22      Andorra          0          0       0
# 4 2020-01-22       Angola          0          0       0

# %%
df.tail(10)
# Out:
#             Date             Country  Confirmed  Recovered  Deaths
# 23678 2020-05-26      United Kingdom     266599       1161   37130
# 23679 2020-05-26             Uruguay        789        638      22
# 23680 2020-05-26          Uzbekistan       3290       2636      14
# 23681 2020-05-26           Venezuela       1211        302      11
# 23682 2020-05-26             Vietnam        327        272       0
# 23683 2020-05-26  West Bank and Gaza        429        365       3
# 23684 2020-05-26      Western Sahara          9          6       1
# 23685 2020-05-26               Yemen        249         10      49
# 23686 2020-05-26              Zambia        920        336       7
# 23687 2020-05-26            Zimbabwe         56         25       4

# %%
df.describe()
# Out:
#           Confirmed      Recovered        Deaths
# count  2.368800e+04   23688.000000  23688.000000
# mean   7.969368e+03    2581.801714    526.935030
# std    5.842109e+04   15143.101257   3992.815956
# min    0.000000e+00       0.000000      0.000000
# 25%    0.000000e+00       0.000000      0.000000
# 50%    1.800000e+01       1.000000      0.000000
# 75%    7.300000e+02     123.000000     13.000000
# max    1.680913e+06  384902.000000  98913.000000

# %%
df.coloumns = ['Date','Country','Recovered','Deaths','Confirmed']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
today = df[df.Date=='2020-05-26']

# %%
today
# Out:
#             Date             Country  Confirmed  Recovered  Deaths
# 23500 2020-05-26         Afghanistan      11831       1128     220
# 23501 2020-05-26             Albania       1029        803      33
# 23502 2020-05-26             Algeria       8697       4918     617
# 23503 2020-05-26             Andorra        763        676      51
# 23504 2020-05-26              Angola         70         18       4
# ...          ...                 ...        ...        ...     ...
# 23683 2020-05-26  West Bank and Gaza        429        365       3
# 23684 2020-05-26      Western Sahara          9          6       1
# 23685 2020-05-26               Yemen        249         10      49
# 23686 2020-05-26              Zambia        920        336       7
# 23687 2020-05-26            Zimbabwe         56         25       4
#
# [188 rows x 5 columns]

# %%
max_confirmed_cases=today.sort_values(by='Confirmed',ascending=False)
max_confirmed_cases
# Out:
#             Date           Country  Confirmed  Recovered  Deaths
# 23674 2020-05-26                US    1680913     384902   98913
# 23523 2020-05-26            Brazil     391222     158593   24512
# 23640 2020-05-26            Russia     362342     131129    3807
# 23678 2020-05-26    United Kingdom     266599       1161   37130
# 23658 2020-05-26             Spain     236259     150376   27117
# ...          ...               ...        ...        ...     ...
# 23661 2020-05-26          Suriname         11          9       1
# 23604 2020-05-26        MS Zaandam          9          0       2
# 23684 2020-05-26    Western Sahara          9          6       1
# 23632 2020-05-26  Papua New Guinea          8          8       0
# 23598 2020-05-26           Lesotho          2          0       0
#
# [188 rows x 5 columns]

# %%
top_countries_confirmed=max_confirmed_cases[0:5]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Country",y="Confirmed",data=top_countries_confirmed,hue="Country")
plt.show()

# %%
max_death_cases=today.sort_values(by="Deaths",ascending=False)
max_death_cases
# Out:
#             Date         Country  Confirmed  Recovered  Deaths
# 23674 2020-05-26              US    1680913     384902   98913
# 23678 2020-05-26  United Kingdom     266599       1161   37130
# 23585 2020-05-26           Italy     230555     144658   32955
# 23562 2020-05-26          France     182847      65997   28533
# 23658 2020-05-26           Spain     236259     150376   27117
# ...          ...             ...        ...        ...     ...
# 23556 2020-05-26         Eritrea         39         39       0
# 23650 2020-05-26      Seychelles         11         11       0
# 23530 2020-05-26        Cambodia        124        122       0
# 23550 2020-05-26        Dominica         16         16       0
# 23616 2020-05-26        Mongolia        141         37       0
#
# [188 rows x 5 columns]

# %%
top_countries_death=max_death_cases[0:5]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Country",y="Deaths",data=top_countries_death,hue="Country")

# %%
max_cured_cases=today.sort_values(by="Recovered",ascending=False)
max_cured_cases
# Out:
#             Date         Country  Confirmed  Recovered  Deaths
# 23674 2020-05-26              US    1680913     384902   98913
# 23566 2020-05-26         Germany     181200     161967    8372
# 23523 2020-05-26          Brazil     391222     158593   24512
# 23658 2020-05-26           Spain     236259     150376   27117
# 23585 2020-05-26           Italy     230555     144658   32955
# ...          ...             ...        ...        ...     ...
# 23684 2020-05-26  Western Sahara          9          6       1
# 23657 2020-05-26     South Sudan        806          6       8
# 23575 2020-05-26        Holy See         12          2       0
# 23604 2020-05-26      MS Zaandam          9          0       2
# 23598 2020-05-26         Lesotho          2          0       0
#
# [188 rows x 5 columns]

# %%
top_countries_cured=max_cured_cases[0:5]

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="Country",y="Recovered",data=top_countries_cured,hue="Country")
plt.show()

# %%
us=df[df.Country=='US']

# %%
us
# Out:
#             Date Country  Confirmed  Recovered  Deaths
# 174   2020-01-22      US          1          0       0
# 362   2020-01-23      US          1          0       0
# 550   2020-01-24      US          2          0       0
# 738   2020-01-25      US          2          0       0
# 926   2020-01-26      US          5          0       0
# ...          ...     ...        ...        ...     ...
# 22922 2020-05-22      US    1600937     350135   95979
# 23110 2020-05-23      US    1622612     361239   97087
# 23298 2020-05-24      US    1643246     366736   97720
# 23486 2020-05-25      US    1662302     379157   98220
# 23674 2020-05-26      US    1680913     384902   98913
#
# [126 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.lineplot(x="Date",y="Confirmed",data=us,color="g")
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.lineplot(x="Date",y="Deaths",data=us,color="r")
plt.show()

# %%
gr=df[df.Country=='Germany']
gr
# Out:
#             Date  Country  Confirmed  Recovered  Deaths
# 66    2020-01-22  Germany          0          0       0
# 254   2020-01-23  Germany          0          0       0
# 442   2020-01-24  Germany          0          0       0
# 630   2020-01-25  Germany          0          0       0
# 818   2020-01-26  Germany          0          0       0
# ...          ...      ...        ...        ...     ...
# 22814 2020-05-22  Germany     179710     159064    8228
# 23002 2020-05-23  Germany     179986     159716    8261
# 23190 2020-05-24  Germany     180328     160281    8283
# 23378 2020-05-25  Germany     180600     161199    8309
# 23566 2020-05-26  Germany     181200     161967    8372
#
# [126 rows x 5 columns]

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.lineplot(x="Date",y="Confirmed",data=gr,color="g")
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.lineplot(x="Date",y="Deaths",data=gr,color="r")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
us
# Out:
#             Date Country  Confirmed  Recovered  Deaths
# 174   2020-01-22      US          1          0       0
# 362   2020-01-23      US          1          0       0
# 550   2020-01-24      US          2          0       0
# 738   2020-01-25      US          2          0       0
# 926   2020-01-26      US          5          0       0
# ...          ...     ...        ...        ...     ...
# 22922 2020-05-22      US    1600937     350135   95979
# 23110 2020-05-23      US    1622612     361239   97087
# 23298 2020-05-24      US    1643246     366736   97720
# 23486 2020-05-25      US    1662302     379157   98220
# 23674 2020-05-26      US    1680913     384902   98913
#
# [126 rows x 5 columns]

# %%
us['Date']=us['Date'].map(dt.datetime.toordinal)
us.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Date Country  Confirmed  Recovered  Deaths
# 174  737446      US          1          0       0
# 362  737447      US          1          0       0
# 550  737448      US          2          0       0
# 738  737449      US          2          0       0
# 926  737450      US          5          0       0

# %%
x=us['Date']
y=us['Confirmed']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
train, test = train_test_split(us, test_size=0.2, random_state=4)

# %%
lr=LinearRegression()

# %%
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
us.tail()
# Out:
#          Date Country  Confirmed  Recovered  Deaths
# 22922  737567      US    1600937     350135   95979
# 23110  737568      US    1622612     361239   97087
# 23298  737569      US    1643246     366736   97720
# 23486  737570      US    1662302     379157   98220
# 23674  737571      US    1680913     384902   98913

# %%
lr.predict(np.array([[737580]]))
# Out:
# array([[1416526.21002197]])

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

# %%
from sklearn import svm
y=train['Confirmed']
x=train['Date']

# %%
clf = svm.SVR(C=1.0, epsilon=0.2)
clf.fit(np.array(x_train).reshape(-1,1),np.ravel(y_train,order='C'))
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
ytrain_pred = clf.predict(np.array(x).reshape(-1,1))
print("In-sample Mean squared error: %.2f"
      % mean_squared_error(y, ytrain_pred))
# Out:
# In-sample Mean squared error: 607364830363.45

# %%
# Now saving the model using joblib
from sklearn.externals import joblib
# save the model using pickle in a file
joblib.dump(lr,'lr_covid.pkl')
# Out:
# ['lr_covid.pkl']
